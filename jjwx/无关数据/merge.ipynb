# %%
import pandas as pd

# %%
score = pd.read_csv('E:\爬虫\jjwx\无关数据\评分.csv')
score
# Out:
#        b_评分                                          piece_url
# 0       9.2  https://www.jjwxc.net/onebook.php?novelid=3594257
# 1       8.0  https://www.jjwxc.net/onebook.php?novelid=2700105
# 2       9.0  https://www.jjwxc.net/onebook.php?novelid=3533938
# 3       8.4  https://www.jjwxc.net/onebook.php?novelid=2721283
# 4       8.0  https://www.jjwxc.net/onebook.php?novelid=2785565
# ...     ...                                                ...
# 157544  9.1  https://www.jjwxc.net/onebook.php?novelid=4505206
# 157545  8.0  https://www.jjwxc.net/onebook.php?novelid=2204112
# 157546  9.0   https://www.jjwxc.net/onebook.php?novelid=237304
# 157547  8.7  https://www.jjwxc.net/onebook.php?novelid=2520185
# 157548  9.1  https://www.jjwxc.net/onebook.php?novelid=3912855
#
# [157549 rows x 2 columns]

# %%
## 6w
data_6w = pd.read_csv('E:\爬虫\jjwx\作品库所有作品(6w优质数据)\作品库爬取.csv')
data_6w
# Out:
#              a_作者                                         author_url  \
# 0              竹已  https://www.jjwxc.net/oneauthor.php?authorid=1...
# 1           Zoody  https://www.jjwxc.net/oneauthor.php?authorid=3...
# 2              竹已  https://www.jjwxc.net/oneauthor.php?authorid=1...
# 3              栖见  https://www.jjwxc.net/oneauthor.php?authorid=5...
# 4              竹已  https://www.jjwxc.net/oneauthor.php?authorid=1...
# ...           ...                                                ...
# 61543  千佑Alleycat  https://www.jjwxc.net/oneauthor.php?authorid=2...
# 61544        闲云向晚  https://www.jjwxc.net/oneauthor.php?authorid=2...
# 61545       河鳝的脑花  https://www.jjwxc.net/oneauthor.php?authorid=2...
# 61546     聪明机智菜菜菜  https://www.jjwxc.net/oneauthor.php?authorid=1...
# 61547        残阳落暖  https://www.jjwxc.net/oneauthor.php?authorid=6...
#
#                                                piece_url               b_发表时间  \
# ...

# %%
data_6w_score = pd.merge(data_6w, score, on='piece_url', how='left')

# %%
data_6w_score.to_csv('E:\爬虫\jjwx\作品库所有作品(6w优质数据)\作品库爬取.csv', index=False)

# %%
data_32w = pd.read_csv(r'E:\爬虫\jjwx\无差别爬取数据(32w数据)\无差别爬取.csv')
data_32w
# Out:
#          a_作品字数 a_作品状态    a_作者  a_作者所发送红包数  a_小说完本数  a_小说暂停数  a_小说连载数  \
# 0        157033     连载    挖坑不填          40      121       25      173
# 1         60744     连载    一宫兴子          20       18        0       25
# 2         60744     连载    一宫兴子          20       18        0       25
# 3        157033     连载    挖坑不填          40      121       25      173
# 4        157033     连载    挖坑不填          40      121       25      173
# ...         ...    ...     ...         ...      ...      ...      ...
# 318669   146993     连载  写文字的静一         109        1        0        1
# 318670   659250     连载     香酥栗         217       12        0        3
# 318671  2259421     连载     甘缘茶        2792        4        0        7
# 318672    86170     连载    天明未羽           0        2        0        3
# 318673    10732     连载   月落十三月           0        0        0       26
#
#                    a_最后更新时间                       a_最近更新作品  a_被收藏数  ...  \
# ...

# %%
data_32w_score = pd.merge(data_32w, score, on='piece_url', how='left')

# %%
data_32w_score.to_csv(r'E:\爬虫\jjwx\无差别爬取数据(32w数据)\无差别爬取.csv', index=False)

# %%
pd.read_csv('E:\爬虫\jjwx\无差别爬取数据(32w数据)\无差别爬取.csv')
# Out:
#          a_作品字数 a_作品状态    a_作者  a_作者所发送红包数  a_小说完本数  a_小说暂停数  a_小说连载数  \
# 0        157033     连载    挖坑不填          40      121       25      173
# 1         60744     连载    一宫兴子          20       18        0       25
# 2         60744     连载    一宫兴子          20       18        0       25
# 3        157033     连载    挖坑不填          40      121       25      173
# 4        157033     连载    挖坑不填          40      121       25      173
# ...         ...    ...     ...         ...      ...      ...      ...
# 318669   146993     连载  写文字的静一         109        1        0        1
# 318670   659250     连载     香酥栗         217       12        0        3
# 318671  2259421     连载     甘缘茶        2792        4        0        7
# 318672    86170     连载    天明未羽           0        2        0        3
# 318673    10732     连载   月落十三月           0        0        0       26
#
#                    a_最后更新时间                       a_最近更新作品  a_被收藏数  ...  \
# ...
